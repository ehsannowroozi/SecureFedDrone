# %% [markdown]
# # Attack Strength Sensitivity (Supervisor Version)

# %%
import pandas as pddata = {    "Beta": [0.3, 0.5, 0.7],    "Test Accuracy (%)": [94.14, 90.92, 89.77],    "Accuracy Drop (pp)": [3.67, 5.49, 7.70],    "Final Loss": [0.109, 0.247, 0.322],    "Convergence Rounds": [49, 49, 50],    "Std Dev": [0.35, 0.41, 0.50],    "Avg Trusted Clients": [7.8, 7.4, 7.3]}df = pd.DataFrame(data)df

# %%
df.to_csv("attack_strength_sensitivity.csv", index=False)
