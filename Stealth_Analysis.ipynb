# %% [markdown]
# # Stealth Analysis (Supervisor Version)

# %%
import pandas as pddata = {    "Metric": [        "Mean Update Norm",        "Cosine Similarity",        "Watermark Correlation",        "Watermark BER",        "Hash-Chain Validity",        "Behavioral Deviation"    ],    "Pristine": [2.80, 0.90, 0.93, 0.020, 99.76, 0.23],    "Malicious": [2.87, 0.83, 0.65, 0.115, 85.7, 0.70],    "Relative Diff (%)": [4.8, 12.8, 32.0, 523.3, 16.3, 224.9],    "Detectable by Norm": ["No", "No", "Yes", "Yes", "Partial", "Yes"]}df = pd.DataFrame(data)df

# %%
df.to_csv("stealth_analysis.csv", index=False)
