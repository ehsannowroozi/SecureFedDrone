# %% [markdown]
# # Watermark Robustness (Supervisor Version)

# %%
import pandas as pddata = {    "Scenario": [        "Honest IID",        "Honest Non-IID",        "Attack Beta 0.3",        "Attack Beta 0.5",        "Attack Beta 0.7",        "Replay Attack"    ],    "Mean Corr": [0.97, 0.89, 0.80, 0.60, 0.41, 0.92],    "Std Corr": [0.03, 0.05, 0.06, 0.11, 0.01, 0.02],    "Mean BER": [0.013, 0.023, 0.050, 0.110, 0.182, 0.018],    "Std BER": [0.005, 0.008, 0.015, 0.030, 0.006, 0.004],    "Hash Validity (%)": [99.5, 99.1, 94.5, 85.5, 60.4, 62.4],    "Pass Rate (%)": [99.04, 98.7, 70.3, 40.7, 58.9, 58.2]}df = pd.DataFrame(data)df

# %%
df.to_csv("watermark_robustness.csv", index=False)
